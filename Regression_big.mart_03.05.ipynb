# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
dfmart=pd.read_csv(r"E:\Feature engineering\big_mart\train.csv")
dfmart
# Out:
#      Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0              FDA15        9.300          Low Fat         0.016047
# 1              DRC01        5.920          Regular         0.019278
# 2              FDN15       17.500          Low Fat         0.016760
# 3              FDX07       19.200          Regular         0.000000
# 4              NCD19        8.930          Low Fat         0.000000
# ...              ...          ...              ...              ...
# 8518           FDF22        6.865          Low Fat         0.056783
# 8519           FDS36        8.380          Regular         0.046982
# 8520           NCJ29       10.600          Low Fat         0.035186
# 8521           FDN46        7.210          Regular         0.145221
# 8522           DRG01       14.800          Low Fat         0.044878
#
#                   Item_Type  Item_MRP Outlet_Identifier  \
# 0                     Dairy  249.8092            OUT049
# ...

# %%
dfmart.columns
# Out:
# Index(['Item_Identifier', 'Item_Weight', 'Item_Fat_Content', 'Item_Visibility',
#        'Item_Type', 'Item_MRP', 'Outlet_Identifier',
#        'Outlet_Establishment_Year', 'Outlet_Size', 'Outlet_Location_Type',
#        'Outlet_Type', 'Item_Outlet_Sales'],
#       dtype='object')

# %%
dfmart.tail()
# Out:
#      Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 8518           FDF22        6.865          Low Fat         0.056783
# 8519           FDS36        8.380          Regular         0.046982
# 8520           NCJ29       10.600          Low Fat         0.035186
# 8521           FDN46        7.210          Regular         0.145221
# 8522           DRG01       14.800          Low Fat         0.044878
#
#                Item_Type  Item_MRP Outlet_Identifier  \
# 8518         Snack Foods  214.5218            OUT013
# 8519        Baking Goods  108.1570            OUT045
# 8520  Health and Hygiene   85.1224            OUT035
# 8521         Snack Foods  103.1332            OUT018
# 8522         Soft Drinks   75.4670            OUT046
#
#       Outlet_Establishment_Year Outlet_Size Outlet_Location_Type  \
# 8518                       1987        High               Tier 3
# 8519                       2002         NaN               Tier 2
# ...

# %%
dfmart.head()
# Out:
#   Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0           FDA15         9.30          Low Fat         0.016047
# 1           DRC01         5.92          Regular         0.019278
# 2           FDN15        17.50          Low Fat         0.016760
# 3           FDX07        19.20          Regular         0.000000
# 4           NCD19         8.93          Low Fat         0.000000
#
#                Item_Type  Item_MRP Outlet_Identifier  \
# 0                  Dairy  249.8092            OUT049
# 1            Soft Drinks   48.2692            OUT018
# 2                   Meat  141.6180            OUT049
# 3  Fruits and Vegetables  182.0950            OUT010
# 4              Household   53.8614            OUT013
#
#    Outlet_Establishment_Year Outlet_Size Outlet_Location_Type  \
# 0                       1999      Medium               Tier 1
# 1                       2009      Medium               Tier 3
# ...

# %%
dfmart.describe()
# Out:
#        Item_Weight  Item_Visibility     Item_MRP  Outlet_Establishment_Year  \
# count  7060.000000      8523.000000  8523.000000                8523.000000
# mean     12.857645         0.066132   140.992782                1997.831867
# std       4.643456         0.051598    62.275067                   8.371760
# min       4.555000         0.000000    31.290000                1985.000000
# 25%       8.773750         0.026989    93.826500                1987.000000
# 50%      12.600000         0.053931   143.012800                1999.000000
# 75%      16.850000         0.094585   185.643700                2004.000000
# max      21.350000         0.328391   266.888400                2009.000000
#
#        Item_Outlet_Sales
# count        8523.000000
# mean         2181.288914
# std          1706.499616
# min            33.290000
# 25%           834.247400
# 50%          1794.331000
# 75%          3101.296400
# max         13086.964800

# %%
dfmart.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8523 entries, 0 to 8522
# Data columns (total 12 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Item_Identifier            8523 non-null   object
#  1   Item_Weight                7060 non-null   float64
#  2   Item_Fat_Content           8523 non-null   object
#  3   Item_Visibility            8523 non-null   float64
#  4   Item_Type                  8523 non-null   object
#  5   Item_MRP                   8523 non-null   float64
#  6   Outlet_Identifier          8523 non-null   object
#  7   Outlet_Establishment_Year  8523 non-null   int64
#  8   Outlet_Size                6113 non-null   object
#  9   Outlet_Location_Type       8523 non-null   object
#  10  Outlet_Type                8523 non-null   object
#  11  Item_Outlet_Sales          8523 non-null   float64
# dtypes: float64(4), int64(1), object(7)
# memory usage: 799.2+ KB

# %%
dfmart.isna().sum()
# Out:
# Item_Identifier                 0
# Item_Weight                  1463
# Item_Fat_Content                0
# Item_Visibility                 0
# Item_Type                       0
# Item_MRP                        0
# Outlet_Identifier               0
# Outlet_Establishment_Year       0
# Outlet_Size                  2410
# Outlet_Location_Type            0
# Outlet_Type                     0
# Item_Outlet_Sales               0
# dtype: int64

# %%
dfmart['Outlet_Size'].unique()
# Out:
# array(['Medium', nan, 'High', 'Small'], dtype=object)

# %%
dfmart['Outlet_Type'].unique()
# Out:
# array(['Supermarket Type1', 'Supermarket Type2', 'Grocery Store',
#        'Supermarket Type3'], dtype=object)

# %%
 dfmart[['Outlet_Size','Outlet_Type']].sample()
# Out:
#      Outlet_Size        Outlet_Type
# 6503        High  Supermarket Type1

# %%
 dfmart[['Outlet_Size','Outlet_Type']].sample(30)
# Out:
#      Outlet_Size        Outlet_Type
# 7336      Medium  Supermarket Type2
# 3186      Medium  Supermarket Type1
# 5602        High  Supermarket Type1
# 3074       Small  Supermarket Type1
# 177          NaN      Grocery Store
# 7458       Small  Supermarket Type1
# 3268         NaN  Supermarket Type1
# 6882         NaN      Grocery Store
# 7305         NaN      Grocery Store
# 8266        High  Supermarket Type1
# 6968        High  Supermarket Type1
# 3247         NaN      Grocery Store
# 6061         NaN  Supermarket Type1
# 2712       Small  Supermarket Type1
# 6749       Small  Supermarket Type1
# 1160      Medium  Supermarket Type2
# 8513       Small  Supermarket Type1
# 8496         NaN  Supermarket Type1
# 232          NaN  Supermarket Type1
# 1681         NaN  Supermarket Type1
# 4522      Medium  Supermarket Type1
# 5454      Medium  Supermarket Type2
# 2231       Small  Supermarket Type1
# 6515      Medium  Supermarket Type2
# 5136       Small  Supermarket Type1
# ...

# %%
dfmart['Outlet_Identifier'].unique()
# Out:
# array(['OUT049', 'OUT018', 'OUT010', 'OUT013', 'OUT027', 'OUT045',
#        'OUT017', 'OUT046', 'OUT035', 'OUT019'], dtype=object)

# %%
dfmart.columns
# Out:
# Index(['Item_Identifier', 'Item_Weight', 'Item_Fat_Content', 'Item_Visibility',
#        'Item_Type', 'Item_MRP', 'Outlet_Identifier',
#        'Outlet_Establishment_Year', 'Outlet_Size', 'Outlet_Location_Type',
#        'Outlet_Type', 'Item_Outlet_Sales'],
#       dtype='object')

# %%
dfmart.drop('Outlet_Establishment_Year',axis=1,inplace= True)

# %%
dfmart.isna().sum()
# Out:
# Item_Identifier            0
# Item_Weight             1463
# Item_Fat_Content           0
# Item_Visibility            0
# Item_Type                  0
# Item_MRP                   0
# Outlet_Identifier          0
# Outlet_Size             2410
# Outlet_Location_Type       0
# Outlet_Type                0
# Item_Outlet_Sales          0
# dtype: int64

# %%
dfmart.dtypes
# Out:
# Item_Identifier          object
# Item_Weight             float64
# Item_Fat_Content         object
# Item_Visibility         float64
# Item_Type                object
# Item_MRP                float64
# Outlet_Identifier        object
# Outlet_Size              object
# Outlet_Location_Type     object
# Outlet_Type              object
# Item_Outlet_Sales       float64
# dtype: object

# %%
dfmart.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8523 entries, 0 to 8522
# Data columns (total 11 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Item_Identifier       8523 non-null   object
#  1   Item_Weight           7060 non-null   float64
#  2   Item_Fat_Content      8523 non-null   object
#  3   Item_Visibility       8523 non-null   float64
#  4   Item_Type             8523 non-null   object
#  5   Item_MRP              8523 non-null   float64
#  6   Outlet_Identifier     8523 non-null   object
#  7   Outlet_Size           6113 non-null   object
#  8   Outlet_Location_Type  8523 non-null   object
#  9   Outlet_Type           8523 non-null   object
#  10  Item_Outlet_Sales     8523 non-null   float64
# dtypes: float64(4), object(7)
# memory usage: 732.6+ KB

# %%
dfmart['Item_Weight'].value_counts().count()
# Out:
# 415

# %%
dfmart['Item_Weight'].mean()
# Out:
# 12.857645184135976

# %%
dfmart['Item_Weight'].fillna(dfmart['Item_Weight'].mean().round(3),inplace=True)

# %%
dfmart['Item_Weight']
# Out:
# 0        9.300
# 1        5.920
# 2       17.500
# 3       19.200
# 4        8.930
#          ...
# 8518     6.865
# 8519     8.380
# 8520    10.600
# 8521     7.210
# 8522    14.800
# Name: Item_Weight, Length: 8523, dtype: float64

# %%
dfmart['Outlet_Size'].value_counts()
# Out:
# Outlet_Size
# Medium    2793
# Small     2388
# High       932
# Name: count, dtype: int64

# %%
dfmart['Outlet_Size'].value_counts().count()
# Out:
# 3

# %%
dfmart['Outlet_Size'].mode()[0]
# Out:
# 'Medium'

# %%
dfmart['Outlet_Size'].fillna(dfmart['Outlet_Size'].mode()[0],inplace=True)

# %%
dfmart['Outlet_Size']
# Out:
# 0       Medium
# 1       Medium
# 2       Medium
# 3       Medium
# 4         High
#          ...
# 8518      High
# 8519    Medium
# 8520     Small
# 8521    Medium
# 8522     Small
# Name: Outlet_Size, Length: 8523, dtype: object

# %% [markdown]
# ## Error Detection

# %%
dfmart
# Out:
#      Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0              FDA15        9.300          Low Fat         0.016047
# 1              DRC01        5.920          Regular         0.019278
# 2              FDN15       17.500          Low Fat         0.016760
# 3              FDX07       19.200          Regular         0.000000
# 4              NCD19        8.930          Low Fat         0.000000
# ...              ...          ...              ...              ...
# 8518           FDF22        6.865          Low Fat         0.056783
# 8519           FDS36        8.380          Regular         0.046982
# 8520           NCJ29       10.600          Low Fat         0.035186
# 8521           FDN46        7.210          Regular         0.145221
# 8522           DRG01       14.800          Low Fat         0.044878
#
#                   Item_Type  Item_MRP Outlet_Identifier Outlet_Size  \
# 0                     Dairy  249.8092            OUT049      Medium
# ...

# %%
sns.boxplot(dfmart)
# Out:
# <Axes: >

# %%
sns.boxplot(dfmart["Item_Visibility"])
plt.show()
plt.hist(dfmart["Item_Visibility"],bins=50,rwidth=0.88)
plt.show()
print("skewed ===>",dfmart["Item_Visibility"].skew().round())
# Out:
# skewed ===> 1.0

# %%
plt.title("Item_Outlet_Sales")
sns.boxplot(dfmart["Item_Outlet_Sales"])
plt.show()
plt.hist(dfmart["Item_Outlet_Sales"],bins=50,rwidth=0.88)
plt.show()
print("skewed ===>",dfmart["Item_Outlet_Sales"].skew().round())
# Out:
# skewed ===> 1.0

# %% [markdown]
# ## Error removing with the help of IQR( Inter Quantile Range) with TIMMING

# %%
q1=dfmart['Item_Visibility'].quantile(0.25)
q3=dfmart['Item_Visibility'].quantile(0.75)
iqr=q3-q1
ll=q1-1.5*iqr
ul=q3+1.5*iqr
print(f' q1 ={q1},q3 ={q3}, iqr ={iqr}, ll= {ll}, ul= {ul}')
# Out:
#  q1 =0.0269894775,q3 =0.0945852925, iqr =0.067595815, ll= -0.07440424500000001, ul= 0.195979015

# %%
(dfmart['Item_Visibility']<ll) | (dfmart['Item_Visibility']>ul)
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 8518    False
# 8519    False
# 8520    False
# 8521    False
# 8522    False
# Name: Item_Visibility, Length: 8523, dtype: bool

# %%
dfmart[(dfmart['Item_Visibility']<ll) | (dfmart['Item_Visibility']>ul)]
# Out:
#      Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 49             FDS02       12.858          Regular         0.255395
# 83             NCL18       12.858          Low Fat         0.293418
# 108            DRE60       12.858          low fat         0.278974
# 174            FDI32       17.700          Low Fat         0.291865
# 334            FDC41       12.858          Low Fat         0.204700
# ...              ...          ...              ...              ...
# 8292           FDF56       12.858          Regular         0.209163
# 8345           FDY28       12.858          Regular         0.266397
# 8371           DRA59        8.270          Regular         0.214125
# 8432           FDI16       14.000          Regular         0.227261
# 8509           FDG45        8.100          Low Fat         0.214306
#
#                   Item_Type  Item_MRP Outlet_Identifier Outlet_Size  \
# 49                    Dairy  196.8794            OUT019       Small
# ...

# %%
dfmart=dfmart[(dfmart['Item_Visibility']>=ll) &  (dfmart['Item_Visibility']<=ul)]
dfmart
# Out:
#      Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0              FDA15        9.300          Low Fat         0.016047
# 1              DRC01        5.920          Regular         0.019278
# 2              FDN15       17.500          Low Fat         0.016760
# 3              FDX07       19.200          Regular         0.000000
# 4              NCD19        8.930          Low Fat         0.000000
# ...              ...          ...              ...              ...
# 8518           FDF22        6.865          Low Fat         0.056783
# 8519           FDS36        8.380          Regular         0.046982
# 8520           NCJ29       10.600          Low Fat         0.035186
# 8521           FDN46        7.210          Regular         0.145221
# 8522           DRG01       14.800          Low Fat         0.044878
#
#                   Item_Type  Item_MRP Outlet_Identifier Outlet_Size  \
# 0                     Dairy  249.8092            OUT049      Medium
# ...

# %%
sns.boxplot(dfmart)
plt.show()

# %%
q11=dfmart['Item_Outlet_Sales'].quantile(0.25)
q33=dfmart['Item_Outlet_Sales'].quantile(0.75)
iqr1=q33-q11
lll=q11-1.5*iqr1
ull=q33+1.5*iqr1
print(f' q11 ={q11},q33 ={q33}, iqr ={iqr}, lll= {lll}, ull= {ull}')
# Out:
#  q11 =874.8612,q33 =3124.5994, iqr =0.067595815, lll= -2499.7460999999994, ull= 6499.2067

# %%
(dfmart['Item_Outlet_Sales']<lll) | (dfmart['Item_Outlet_Sales']>ull)
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 8518    False
# 8519    False
# 8520    False
# 8521    False
# 8522    False
# Name: Item_Outlet_Sales, Length: 8379, dtype: bool

# %%
dfmart[(dfmart['Item_Outlet_Sales']<lll) | (dfmart['Item_Outlet_Sales']>ull)]
# Out:
#      Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 43             FDC02       21.350          Low Fat         0.069103
# 130            FDY25       12.858          Low Fat         0.033810
# 132            NCR53       12.858          Low Fat         0.144338
# 145            FDP16       18.600          Low Fat         0.039356
# 203            FDI24       12.858          Low Fat         0.078362
# ...              ...          ...              ...              ...
# 8245           FDU55       16.200          Low Fat         0.035967
# 8329           NCQ06       12.858          Low Fat         0.041622
# 8350           NCE18       10.000          Low Fat         0.021421
# 8447           FDS26       20.350          Low Fat         0.089975
# 8510           FDN58       13.800          Regular         0.056862
#
#                   Item_Type  Item_MRP Outlet_Identifier Outlet_Size  \
# 43                   Canned  259.9278            OUT018      Medium
# ...

# %%
dfmart=dfmart[(dfmart['Item_Outlet_Sales']>=lll) & (dfmart['Item_Outlet_Sales']<=ull)]

# %%
dfmart
# Out:
#      Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0              FDA15        9.300          Low Fat         0.016047
# 1              DRC01        5.920          Regular         0.019278
# 2              FDN15       17.500          Low Fat         0.016760
# 3              FDX07       19.200          Regular         0.000000
# 4              NCD19        8.930          Low Fat         0.000000
# ...              ...          ...              ...              ...
# 8518           FDF22        6.865          Low Fat         0.056783
# 8519           FDS36        8.380          Regular         0.046982
# 8520           NCJ29       10.600          Low Fat         0.035186
# 8521           FDN46        7.210          Regular         0.145221
# 8522           DRG01       14.800          Low Fat         0.044878
#
#                   Item_Type  Item_MRP Outlet_Identifier Outlet_Size  \
# 0                     Dairy  249.8092            OUT049      Medium
# ...

# %%
dfmart.shape
# Out:
# (8193, 11)

# %%
sns.boxplot(dfmart)
plt.show()

# %%
dfmart.describe()
# Out:
#        Item_Weight  Item_Visibility     Item_MRP  Item_Outlet_Sales
# count  8193.000000      8193.000000  8193.000000        8193.000000
# mean     12.863987         0.063221   139.104030        2089.540121
# std       4.266983         0.046285    61.536438        1501.498356
# min       4.555000         0.000000    31.290000          33.290000
# 25%       9.300000         0.026818    92.980400         857.550400
# 50%      12.858000         0.052729   141.147000        1783.678200
# 75%      16.100000         0.092783   183.663400        3020.068800
# max      21.350000         0.195721   266.888400        6478.234000

# %%
dfmart.dtypes
# Out:
# Item_Identifier          object
# Item_Weight             float64
# Item_Fat_Content         object
# Item_Visibility         float64
# Item_Type                object
# Item_MRP                float64
# Outlet_Identifier        object
# Outlet_Size              object
# Outlet_Location_Type     object
# Outlet_Type              object
# Item_Outlet_Sales       float64
# dtype: object

# %%
dfmart['Item_Identifier'].unique()
# Out:
# array(['FDA15', 'DRC01', 'FDN15', ..., 'FDC47', 'NCW30', 'NCW05'],
#       dtype=object)

# %%
dfmart['Item_Identifier'].nunique()
# Out:
# 1559

# %%
dfmart['Item_Identifier'].replace('[^a-zA-Z]',"", regex=True)
# Out:
# 0       FDA
# 1       DRC
# 2       FDN
# 3       FDX
# 4       NCD
#        ...
# 8518    FDF
# 8519    FDS
# 8520    NCJ
# 8521    FDN
# 8522    DRG
# Name: Item_Identifier, Length: 8193, dtype: object

# %%
idententifiers=dfmart['Item_Identifier'].replace('[^a-zA-Z]',"", regex=True)

# %%
idententifiers.unique()
# Out:
# array(['FDA', 'DRC', 'FDN', 'FDX', 'NCD', 'FDP', 'FDO', 'FDH', 'FDU',
#        'FDY', 'FDS', 'FDF', 'NCB', 'DRI', 'FDW', 'FDC', 'FDR', 'FDV',
#        'DRJ', 'FDE', 'NCS', 'DRH', 'NCX', 'DRZ', 'FDB', 'FDK', 'FDL',
#        'FDM', 'NCP', 'NCL', 'DRK', 'FDI', 'FDZ', 'NCI', 'FDJ', 'FDG',
#        'NCZ', 'FDQ', 'FDD', 'DRG', 'NCR', 'FDT', 'DRB', 'DRA', 'NCF',
#        'NCH', 'NCO', 'NCN', 'NCC', 'DRD', 'DRF', 'DRL', 'NCM', 'NCU',
#        'DRY', 'NCW', 'DRM', 'DRE', 'NCT', 'NCQ', 'DRP', 'DRQ', 'NCK',
#        'NCY', 'DRN', 'NCA', 'NCE', 'NCJ', 'NCV', 'NCG', 'DRO'],
#       dtype=object)

# %%
idententifiers.nunique()
# Out:
# 71

# %%
df1= pd.DataFrame(idententifiers)
df1
# Out:
#      Item_Identifier
# 0                FDA
# 1                DRC
# 2                FDN
# 3                FDX
# 4                NCD
# ...              ...
# 8518             FDF
# 8519             FDS
# 8520             NCJ
# 8521             FDN
# 8522             DRG
#
# [8193 rows x 1 columns]

# %%
df1['Item_Identifier']=df1['Item_Identifier'].map(lambda x: x[:2])
df1['Item_Identifier']
# Out:
# 0       FD
# 1       DR
# 2       FD
# 3       FD
# 4       NC
#         ..
# 8518    FD
# 8519    FD
# 8520    NC
# 8521    FD
# 8522    DR
# Name: Item_Identifier, Length: 8193, dtype: object

# %%
df1['Item_ID_name']=df1['Item_Identifier'].map(lambda x: "Food" if x=="FD" else  "Drinks" if x=="DR" else "Non-Consumable" )
df1
# Out:
#      Item_Identifier    Item_ID_name
# 0                 FD            Food
# 1                 DR          Drinks
# 2                 FD            Food
# 3                 FD            Food
# 4                 NC  Non-Consumable
# ...              ...             ...
# 8518              FD            Food
# 8519              FD            Food
# 8520              NC  Non-Consumable
# 8521              FD            Food
# 8522              DR          Drinks
#
# [8193 rows x 2 columns]

# %%
dfmart.Item_Fat_Content.unique()
# Out:
# array(['Low Fat', 'Regular', 'low fat', 'LF', 'reg'], dtype=object)

# %%
dfmart.Item_Fat_Content.map(lambda x: "Low Fat" if x in ['Low Fat', 'low fat', 'LF'] else "Regular")
# Out:
# 0       Low Fat
# 1       Regular
# 2       Low Fat
# 3       Regular
# 4       Low Fat
#          ...
# 8518    Low Fat
# 8519    Regular
# 8520    Low Fat
# 8521    Regular
# 8522    Low Fat
# Name: Item_Fat_Content, Length: 8193, dtype: object

# %%
dfmart.Item_Fat_Content.map(lambda x: "Low Fat" if x in ['Low Fat', 'low fat', 'LF'] else "Regular").unique()
# Out:
# array(['Low Fat', 'Regular'], dtype=object)

# %%
dfmart['Item_Fat_Content']=dfmart['Item_Fat_Content'].map(lambda x: "Low Fat" if x in ['Low Fat', 'low fat', 'LF'] else "Regular")
dfmart['Item_Fat_Content']
# Out:
# C:\Users\Laxman Suryawanshi\AppData\Local\Temp\ipykernel_35256\2137247701.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dfmart['Item_Fat_Content']=dfmart['Item_Fat_Content'].map(lambda x: "Low Fat" if x in ['Low Fat', 'low fat', 'LF'] else "Regular")
# 0       Low Fat
# 1       Regular
# 2       Low Fat
# 3       Regular
# 4       Low Fat
#          ...
# 8518    Low Fat
# 8519    Regular
# 8520    Low Fat
# 8521    Regular
# 8522    Low Fat
# Name: Item_Fat_Content, Length: 8193, dtype: object

# %%
dfmart
# Out:
#      Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0              FDA15        9.300          Low Fat         0.016047
# 1              DRC01        5.920          Regular         0.019278
# 2              FDN15       17.500          Low Fat         0.016760
# 3              FDX07       19.200          Regular         0.000000
# 4              NCD19        8.930          Low Fat         0.000000
# ...              ...          ...              ...              ...
# 8518           FDF22        6.865          Low Fat         0.056783
# 8519           FDS36        8.380          Regular         0.046982
# 8520           NCJ29       10.600          Low Fat         0.035186
# 8521           FDN46        7.210          Regular         0.145221
# 8522           DRG01       14.800          Low Fat         0.044878
#
#                   Item_Type  Item_MRP Outlet_Identifier Outlet_Size  \
# 0                     Dairy  249.8092            OUT049      Medium
# ...

# %%
dfmart['Item_Type']
# Out:
# 0                       Dairy
# 1                 Soft Drinks
# 2                        Meat
# 3       Fruits and Vegetables
# 4                   Household
#                 ...
# 8518              Snack Foods
# 8519             Baking Goods
# 8520       Health and Hygiene
# 8521              Snack Foods
# 8522              Soft Drinks
# Name: Item_Type, Length: 8193, dtype: object

# %%
dfmart['Item_Type'].unique()
# Out:
# array(['Dairy', 'Soft Drinks', 'Meat', 'Fruits and Vegetables',
#        'Household', 'Baking Goods', 'Snack Foods', 'Frozen Foods',
#        'Breakfast', 'Health and Hygiene', 'Hard Drinks', 'Canned',
#        'Breads', 'Starchy Foods', 'Others', 'Seafood'], dtype=object)

# %%
dfmart['Item_Type'].nunique()
# Out:
# 16

# %%
dfmart['Outlet_Identifier'].unique()
# Out:
# array(['OUT049', 'OUT018', 'OUT010', 'OUT013', 'OUT027', 'OUT045',
#        'OUT017', 'OUT046', 'OUT035', 'OUT019'], dtype=object)

# %%
dfmart['Outlet_Identifier'].nunique()
# Out:
# 10

# %%
dfmart['Outlet_Size'].unique()
# Out:
# array(['Medium', 'High', 'Small'], dtype=object)

# %%
dfmart['Outlet_Size'].nunique()
# Out:
# 3

# %%
dfmart['Outlet_Location_Type'].unique()
# Out:
# array(['Tier 1', 'Tier 3', 'Tier 2'], dtype=object)

# %%
dfmart['Outlet_Location_Type'].nunique()
# Out:
# 3

# %%
dfmart['Outlet_Location_Type'].value_counts()
# Out:
# Outlet_Location_Type
# Tier 3    3162
# Tier 2    2741
# Tier 1    2290
# Name: count, dtype: int64

# %%
dfmart.dtypes
# Out:
# Item_Identifier          object
# Item_Weight             float64
# Item_Fat_Content         object
# Item_Visibility         float64
# Item_Type                object
# Item_MRP                float64
# Outlet_Identifier        object
# Outlet_Size              object
# Outlet_Location_Type     object
# Outlet_Type              object
# Item_Outlet_Sales       float64
# dtype: object

# %%
dfmart.dtypes[dfmart.dtypes == "object"].index
# Out:
# Index(['Item_Identifier', 'Item_Fat_Content', 'Item_Type', 'Outlet_Identifier',
#        'Outlet_Size', 'Outlet_Location_Type', 'Outlet_Type'],
#       dtype='object')

# %%
col=[ 'Item_Fat_Content','Outlet_Size', 'Outlet_Location_Type', 'Outlet_Type']

# %%
col
# Out:
# ['Item_Fat_Content', 'Outlet_Size', 'Outlet_Location_Type', 'Outlet_Type']

# %%
from sklearn.preprocessing import OrdinalEncoder

# %%
for i in col:
    ord= OrdinalEncoder()
    ord.fit(dfmart[[i]])
    dfmart[i]=ord.transform(dfmart[[i]])
# Out:
# C:\Users\Laxman Suryawanshi\AppData\Local\Temp\ipykernel_35256\1793498635.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dfmart[i]=ord.transform(dfmart[[i]])
# C:\Users\Laxman Suryawanshi\AppData\Local\Temp\ipykernel_35256\1793498635.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dfmart[i]=ord.transform(dfmart[[i]])
# C:\Users\Laxman Suryawanshi\AppData\Local\Temp\ipykernel_35256\1793498635.py:4: SettingWithCopyWarning:
# ...

# %%
dfmart.dtypes
# Out:
# Item_Identifier          object
# Item_Weight             float64
# Item_Fat_Content        float64
# Item_Visibility         float64
# Item_Type                object
# Item_MRP                float64
# Outlet_Identifier        object
# Outlet_Size             float64
# Outlet_Location_Type    float64
# Outlet_Type             float64
# Item_Outlet_Sales       float64
# dtype: object

# %%
dfmart1 = pd.get_dummies(dfmart,drop_first=True)
dfmart1
# Out:
#       Item_Weight  Item_Fat_Content  Item_Visibility  Item_MRP  Outlet_Size  \
# 0           9.300               0.0         0.016047  249.8092          1.0
# 1           5.920               1.0         0.019278   48.2692          1.0
# 2          17.500               0.0         0.016760  141.6180          1.0
# 3          19.200               1.0         0.000000  182.0950          1.0
# 4           8.930               0.0         0.000000   53.8614          0.0
# ...           ...               ...              ...       ...          ...
# 8518        6.865               0.0         0.056783  214.5218          0.0
# 8519        8.380               1.0         0.046982  108.1570          1.0
# 8520       10.600               0.0         0.035186   85.1224          2.0
# 8521        7.210               1.0         0.145221  103.1332          1.0
# 8522       14.800               0.0         0.044878   75.4670          2.0
#
# ...

# %%
dfmart1.replace([True,False],[1,0])
# Out:
#       Item_Weight  Item_Fat_Content  Item_Visibility  Item_MRP  Outlet_Size  \
# 0           9.300               0.0         0.016047  249.8092          1.0
# 1           5.920               1.0         0.019278   48.2692          1.0
# 2          17.500               0.0         0.016760  141.6180          1.0
# 3          19.200               1.0         0.000000  182.0950          1.0
# 4           8.930               0.0         0.000000   53.8614          0.0
# ...           ...               ...              ...       ...          ...
# 8518        6.865               0.0         0.056783  214.5218          0.0
# 8519        8.380               1.0         0.046982  108.1570          1.0
# 8520       10.600               0.0         0.035186   85.1224          2.0
# 8521        7.210               1.0         0.145221  103.1332          1.0
# 8522       14.800               0.0         0.044878   75.4670          2.0
#
# ...

# %%
dfmart1 = dfmart1.replace([True,False],[1,0])

# %%
dfmart1
# Out:
#       Item_Weight  Item_Fat_Content  Item_Visibility  Item_MRP  Outlet_Size  \
# 0           9.300               0.0         0.016047  249.8092          1.0
# 1           5.920               1.0         0.019278   48.2692          1.0
# 2          17.500               0.0         0.016760  141.6180          1.0
# 3          19.200               1.0         0.000000  182.0950          1.0
# 4           8.930               0.0         0.000000   53.8614          0.0
# ...           ...               ...              ...       ...          ...
# 8518        6.865               0.0         0.056783  214.5218          0.0
# 8519        8.380               1.0         0.046982  108.1570          1.0
# 8520       10.600               0.0         0.035186   85.1224          2.0
# 8521        7.210               1.0         0.145221  103.1332          1.0
# 8522       14.800               0.0         0.044878   75.4670          2.0
#
# ...

# %% [markdown]
# ## Data Separation

# %%
x=dfmart1.drop("Item_Outlet_Sales", axis = 1)
x
# Out:
#       Item_Weight  Item_Fat_Content  Item_Visibility  Item_MRP  Outlet_Size  \
# 0           9.300               0.0         0.016047  249.8092          1.0
# 1           5.920               1.0         0.019278   48.2692          1.0
# 2          17.500               0.0         0.016760  141.6180          1.0
# 3          19.200               1.0         0.000000  182.0950          1.0
# 4           8.930               0.0         0.000000   53.8614          0.0
# ...           ...               ...              ...       ...          ...
# 8518        6.865               0.0         0.056783  214.5218          0.0
# 8519        8.380               1.0         0.046982  108.1570          1.0
# 8520       10.600               0.0         0.035186   85.1224          2.0
# 8521        7.210               1.0         0.145221  103.1332          1.0
# 8522       14.800               0.0         0.044878   75.4670          2.0
#
# ...

# %%
y=dfmart1['Item_Outlet_Sales']
y
# Out:
# 0       3735.1380
# 1        443.4228
# 2       2097.2700
# 3        732.3800
# 4        994.7052
#           ...
# 8518    2778.3834
# 8519     549.2850
# 8520    1193.1136
# 8521    1845.5976
# 8522     765.6700
# Name: Item_Outlet_Sales, Length: 8193, dtype: float64

# %%
from sklearn.model_selection import train_test_split

# %%
xtrain,xtest,ytrain,ytest= train_test_split(x,y,test_size=0.20)

# %%
xtrain.shape,xtest.shape,x.shape
# Out:
# ((6554, 1589), (1639, 1589), (8193, 1589))

# %%
ytrain.shape,ytest.shape,y.shape
# Out:
# ((6554,), (1639,), (8193,))

# %%
from sklearn.linear_model import LinearRegression
lrmodel=LinearRegression()
lrmodel
# Out:
# LinearRegression()

# %%
lrmodel.fit(xtrain,ytrain)
# Out:
# LinearRegression()

# %%
lrmodel.score(xtest,ytest)
# Out:
# 0.38451556074724436

# %%
lrmodel.score(xtrain,ytrain)
# Out:
# 0.6645740551375582

# %%
score=[]
for i in range(300):
    xtain,xtest,ytrain,ytest= train_test_split(x,y,test_size=0.20,random_state=i)
    lreg= LinearRegression()
    lreg.fit(xtrain,ytrain)
    sc=lreg.score(xtest,ytest)
    score.append(sc)
max=max(score)
print(f'Maximum score is {max}')
print(score.index(max))
# Out:
# Maximum score is -0.1818522160396263
# 220
